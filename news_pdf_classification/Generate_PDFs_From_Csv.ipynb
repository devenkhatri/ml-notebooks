# %%
pip install PyPDF2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 5.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Read the CSV

# %%
import PyPDF2 as pypdf
import pandas as pd

data =pd.read_csv('bbc-text.csv')#preserving  original data for future use
# data.text

# writer = PdfWriter()

# Add news as page in pdf

# Add new category as tag in pdf
# writer.add_metadata(
#     {
#         "/Tag": "Martin",

#     }
# )

# Save the new PDF to a file
# with open("meta-pdf.pdf", "wb") as f:
#     writer.write(f)

# %%
# !pip3 install fpdf2
import fpdf

pdf = fpdf.FPDF(format='letter') #pdf format
pdf.add_page() #create new page
pdf.set_font("helvetica", "B", 16)
pdf.cell(40, 10, "Hello World!")
pdf.output("test.pdf")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.1/187.1 kB 3.7 MB/s eta 0:00:00
# ...
# ''

# %% [markdown]
# ## Iterate through all the rows of CSV

# %%
for index, row in data.iterrows():
  filename = str(index) + "_" + row.category +".pdf"
  # print(filename)

  writer = pypdf.PdfWriter()

  # Create a new PdfPage() object.
  page = writer.add_blank_page(width=595.3, height=841.9)

  print(page)

# Write the PDF to a new file called 'output.pdf'.
  # writer.write('output.pdf')

  # page = writer.add_blank_page(width=595.3, height=841.9)
  # # page.drawString(0, 0, row.text)
  # page._data_stream = row.text
  # writer.add_page(page)

  # # Save the new PDF to a file
  # with open(filename, "wb") as f:
  #   writer.write(f)
# Out:
# {'/Type': '/Page', '/Parent': NullObject, '/Resources': {}, '/MediaBox': RectangleObject([0, 0, 595.299999999999954525264911353588104248046875, 841.8999999999999772626324556767940521240234375])}
# {'/Type': '/Page', '/Parent': NullObject, '/Resources': {}, '/MediaBox': RectangleObject([0, 0, 595.299999999999954525264911353588104248046875, 841.8999999999999772626324556767940521240234375])}
# {'/Type': '/Page', '/Parent': NullObject, '/Resources': {}, '/MediaBox': RectangleObject([0, 0, 595.299999999999954525264911353588104248046875, 841.8999999999999772626324556767940521240234375])}
# {'/Type': '/Page', '/Parent': NullObject, '/Resources': {}, '/MediaBox': RectangleObject([0, 0, 595.299999999999954525264911353588104248046875, 841.8999999999999772626324556767940521240234375])}
# {'/Type': '/Page', '/Parent': NullObject, '/Resources': {}, '/MediaBox': RectangleObject([0, 0, 595.299999999999954525264911353588104248046875, 841.8999999999999772626324556767940521240234375])}
# ...
